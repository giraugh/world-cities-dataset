# %%
import pandas as pd

# %%
df = pd.read_csv("./cities_custom.csv")

# %%
df
# Out:
#       continent country          country_name                    name  \
# 0            EU      AD               Andorra            les Escaldes
# 1            EU      AD               Andorra        Andorra la Vella
# 2            AS      AE  United Arab Emirates                 Warīsān
# 3            AS      AE  United Arab Emirates              Umm Suqaym
# 4            AS      AE  United Arab Emirates      Umm Al Quwain City
# ...         ...     ...                   ...                     ...
# 32802        AF      ZW              Zimbabwe                 Bindura
# 32803        AF      ZW              Zimbabwe              Beitbridge
# 32804        AF      ZW              Zimbabwe                 Epworth
# 32805        AF      ZW              Zimbabwe             Chitungwiza
# 32806        AF      ZW              Zimbabwe  Harare Western Suburbs
#
#             lat       lng  population           capital
# 0      42.50729   1.53414       15853  Andorra la Vella
# ...

# %%
big_cities = df[df['population'] > 300_000]

# %%
len(big_cities)
# Out:
# 1890

# %%
df[df['name'] == 'Gaza']
# Out:
#       continent country           country_name  name       lat       lng  \
# 24356        AS      PS  Palestinian Territory  Gaza  31.50161  34.46672
#
#        population         capital
# 24356      410000  East Jerusalem

# %%
big_cities['country_name'].unique()
# Out:
# array(['United Arab Emirates', 'Afghanistan', 'Albania', 'Armenia',
#        'Angola', 'Argentina', 'Austria', 'Australia', 'Azerbaijan',
#        'Bosnia and Herzegovina', 'Bangladesh', 'Belgium', 'Burkina Faso',
#        'Bulgaria', 'Burundi', 'Benin', 'Bolivia', 'Brazil', 'Belarus',
#        'Canada', 'Democratic Republic of the Congo',
#        'Central African Republic', 'Republic of the Congo', 'Switzerland',
#        'Ivory Coast', 'Chile', 'Cameroon', 'China', 'Colombia',
#        'Costa Rica', 'Cuba', 'Czechia', 'Germany', 'Djibouti', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Estonia', 'Egypt',
#        'Eritrea', 'Spain', 'Ethiopia', 'Finland', 'France', 'Gabon',
#        'United Kingdom', 'Georgia', 'Ghana', 'Gambia', 'Guinea', 'Greece',
#        'Guatemala', 'Guinea-Bissau', 'Hong Kong', 'Honduras', 'Croatia',
#        'Haiti', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'India',
# ...

# %% [markdown]
# ## Lets try biggest per country

# %%
largest_pc = df.groupby("country_name", group_keys=False).apply(
    lambda g: g.nlargest(3, "population"),
)
# Out:
# /var/folders/2s/94bfrtl11z91_vr4k62dqzzm0000gn/T/ipykernel_5049/2745417061.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   largest_pc = df.groupby("country_name", group_keys=False).apply(

# %%
import random

# %%
lines = []
for i,row in big_cities.iterrows():
    line = f'{row["name"]}, {row["country_name"]}'
    if len(line) < 30:
        lines.append(line)
lines
# Out:
# ['Dubai, United Arab Emirates',
#  'Dayrah, United Arab Emirates',
#  'Sharjah, United Arab Emirates',
#  'Mazār-e Sharīf, Afghanistan',
#  'Kandahār, Afghanistan',
#  'Kabul, Afghanistan',
#  'Herāt, Afghanistan',
#  'Tirana, Albania',
#  'Yerevan, Armenia',
#  'Saurimo, Angola',
#  'Uíge, Angola',
#  'Malanje, Angola',
#  'Luanda, Angola',
#  'Cabinda, Angola',
#  'Lubango, Angola',
#  'Lobito, Angola',
#  'Cuíto, Angola',
#  'Huambo, Angola',
#  'Benguela, Angola',
#  'Posadas, Argentina',
#  'Mar del Plata, Argentina',
#  'Corrientes, Argentina',
#  'Buenos Aires, Argentina',
#  'Santa Fe, Argentina',
#  'Salta, Argentina',
#  'Rosario, Argentina',
#  'Córdoba, Argentina',
#  'Vienna, Austria',
#  'Graz, Austria',
#  'Perth, Australia',
#  'Adelaide, Australia',
#  'Sydney, Australia',
#  'Newcastle, Australia',
#  'Melbourne, Australia',
#  'Gold Coast, Australia',
#  'Canberra, Australia',
#  'Brisbane, Australia',
#  'Logan City, Australia',
#  'Sunshine Coast, Australia',
# ...

# %%
{ random.choice(lines) for i in range(10) }
# Out:
# {'Cheongju-si, South Korea',
#  'Daye, China',
#  'Douala, Cameroon',
#  'Glasgow, United Kingdom',
#  'Lhoka, China',
#  'Muscat, Oman',
#  'Nantes, France',
#  'San Francisco, United States',
#  'Solwezi, Zambia',
#  'Vladimir, Russia'}

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['population'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10e4bfa70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10e4c0080>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10e4bf7a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x10e4c0710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10e4c0a70>],
#  'means': []}
